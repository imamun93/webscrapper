# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
import lxml.html as lh
from tabulate import tabulate

# %%
url= 'https://www.nasdaq.com/symbol/fdx/financials?query=income-statement&data=quarterly&fbclid=IwAR1PxBLQIR_0XZdv1Ow1rqycxw5YPt2euihA_wHWj6dKhTEejqzSa3KCEyU'

# %%
res = requests.get(url)
print(res)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.content)

# %%
table = soup.find_all('table')

# %%
print(table)
# Out:
# [<table class="marginL5px" width="415">
# <tr><td> </td></tr>
# <tr><td><h2>Symbol Lookup</h2></td></tr>
# </table>, <table class="backdrop" id="customModal">
# <tr>
# <td>
# <!-- begin lightboxness -->
# <div class="lightbox" id="followPromo">
# <!-- close button-->
# <span class="close" onclick="close_modal()">CLOSE<span class="x">X</span></span>
# <h2>Investing just got easier…</h2>
# <h4>Sign up now to become a NASDAQ.com member and begin receiving instant notifications when key events occur that affect the stocks you follow.</h4>
# <a class="faux-button lightgreen-button" href="https://community.nasdaq.com/" onclick="triggerAsyncOmnitureClickEvent('quotes:faux-follow:access-now')">
# <span>Access Now</span>
# </a>
# <div class="clearB"></div>
# </div>
# <!-- end lightboxness -->
# </td>
# </tr>
# </table>, <table>
# <thead>
# <tr>
# <th>Quarter:</th>
# <th class="TalignL">Trend</th>
# <th>3rd</th>
# <th>2nd</th>
# <th>1st</th>
# <th>4th</th>
# </tr>
# <tr>
# ...

# %%
df = pd.read_html(str(table))

# %%
print(df)
# Out:
# [               0
# 0  Symbol Lookup,                                                    0
# 0  CLOSEX Investing just got easier… Sign up now ...,                                           Quarter:               Trend  \
#                                    Quarter Ending:  Unnamed: 1_level_1
# 0                                    Total Revenue                 NaN
# 1                                  Cost of Revenue                 NaN
# 2                                     Gross Profit                 NaN
# 3                               Operating Expenses  Operating Expenses
# 4                         Research and Development                 NaN
# 5                        Sales, General and Admin.                 NaN
# 6                              Non-Recurring Items                 NaN
# 7                            Other Operating Items                 NaN
# 8                                 Operating Income                 NaN
# ...

# %%
type(df)
# Out:
# list

# %%
df= pd.DataFrame(df)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
meraz2=df.to_csv('meraz2', encoding='utf-8', index=False)

# %%
marz= df.to_csv(index = None)
marz
# Out:
# '0\n"               0\n0  Symbol Lookup"\n"                                                   0\n0  CLOSEX Investing just got easier… Sign up now ..."\n"                                          Quarter:               Trend  \\\n                                   Quarter Ending:  Unnamed: 1_level_1   \n0                                    Total Revenue                 NaN   \n1                                  Cost of Revenue                 NaN   \n2                                     Gross Profit                 NaN   \n3                               Operating Expenses  Operating Expenses   \n4                         Research and Development                 NaN   \n5                        Sales, General and Admin.                 NaN   \n6                              Non-Recurring Items                 NaN   \n7                            Other Operating Items                 NaN   \n8                                 Operating Income                 NaN   \n9                  
# ...
